# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e1243bd22c6> in <cell line: 0>()
# ----> 1 test
#
# NameError: name 'test' is not defined
